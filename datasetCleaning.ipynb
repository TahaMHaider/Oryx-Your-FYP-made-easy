# %%
import pandas as pd
df=pd.read_csv('F:/6samester/AI/Project/Houseslist.csv')
df
# Out:
#         SR#    Prog    RollNo                       Name
# 0       1.0     BBA  14K-2712                    Pirkash
# 1       2.0     BBA  15K-2717               Vinesh Kumar
# 2       3.0     BBA  16K-2709    Syed Taimoor Bin Naseem
# 3       4.0     BBA  16K-2723                  Sehar Ali
# 4       5.0     BBA  16K-2736             Muhammad Bilal
# ...     ...     ...       ...                        ...
# 2093  414.0  BS(SE)  19K-1100               Hammad Ahmed
# 2094  415.0  BS(SE)  19K-1106                Fizza Zakir
# 2095  416.0  BS(SE)  19K-1111       M Aamir Hassan Malik
# 2096  417.0  BS(SE)  19K-1116                     Sarmad
# 2097  418.0  BS(SE)  19K-1121  Syed Muhammad Wahaj Kazmi
#
# [2098 rows x 4 columns]

# %%
for i in range(0,2098):
    df.loc[i,['SR#']] = i

# %%
df
# Out:
#          SR# Prog    RollNo                     Name
# 0        0.0  BBA  14K-2712                  Pirkash
# 1        1.0  BBA  15K-2717             Vinesh Kumar
# 2        2.0  BBA  16K-2709  Syed Taimoor Bin Naseem
# 3        3.0  BBA  16K-2723                Sehar Ali
# 4        4.0  BBA  16K-2736           Muhammad Bilal
# ...      ...  ...       ...                      ...
# 2995  2995.0  NaN       NaN                      NaN
# 2996  2996.0  NaN       NaN                      NaN
# 2997  2997.0  NaN       NaN                      NaN
# 2998  2998.0  NaN       NaN                      NaN
# 2999  2999.0  NaN       NaN                      NaN
#
# [3000 rows x 4 columns]

# %%
df.dropna()
# Out:
#          SR#    Prog    RollNo                       Name
# 0        0.0     BBA  14K-2712                    Pirkash
# 1        1.0     BBA  15K-2717               Vinesh Kumar
# 2        2.0     BBA  16K-2709    Syed Taimoor Bin Naseem
# 3        3.0     BBA  16K-2723                  Sehar Ali
# 4        4.0     BBA  16K-2736             Muhammad Bilal
# ...      ...     ...       ...                        ...
# 2093  2093.0  BS(SE)  19K-1100               Hammad Ahmed
# 2094  2094.0  BS(SE)  19K-1106                Fizza Zakir
# 2095  2095.0  BS(SE)  19K-1111       M Aamir Hassan Malik
# 2096  2096.0  BS(SE)  19K-1116                     Sarmad
# 2097  2097.0  BS(SE)  19K-1121  Syed Muhammad Wahaj Kazmi
#
# [2097 rows x 4 columns]

# %%
fieldsList=['Computer Science',
'Computer Engineering',
'Information Systems',
'Information Technology (IT)',
'Information Science',
      'Cyber Security',
      'deep learning',
      'Natural Processing Language NLP',
      'Machine Learning',
      'Web development',
      'Mobile Application Development',
      'Network Security',
      'Artificial Intellegence',
      'internet of things',
      'Data science']

# %%
import random

# print(random.choice(fieldsList))

# %%
for i in range(0,2098):
    df.loc[i,['Domains']] = random.choice(fieldsList)

# %%
df.head(5)
# Out:
#    SR# Prog    RollNo                     Name           Domains
# 0  0.0  BBA  14K-2712                  Pirkash     deep learning
# 1  1.0  BBA  15K-2717             Vinesh Kumar      Data science
# 2  2.0  BBA  16K-2709  Syed Taimoor Bin Naseem  Computer Science
# 3  3.0  BBA  16K-2723                Sehar Ali  Network Security
# 4  4.0  BBA  16K-2736           Muhammad Bilal  Computer Science

# %%
df.to_csv(r'F:/6samester/AI/Project/students.csv')

# %%
df1=pd.read_csv('F:/6samester/AI/Project/students.csv')
del df1['SR#']

# %%
df1
# Out:
#       SR#.1 Prog    RollNo                     Name           Domains
# 0         0  BBA  14K-2712                  Pirkash     deep learning
# 1         1  BBA  15K-2717             Vinesh Kumar      Data science
# 2         2  BBA  16K-2709  Syed Taimoor Bin Naseem  Computer Science
# 3         3  BBA  16K-2723                Sehar Ali  Network Security
# 4         4  BBA  16K-2736           Muhammad Bilal  Computer Science
# ...     ...  ...       ...                      ...               ...
# 2995   2995  NaN       NaN                      NaN               NaN
# 2996   2996  NaN       NaN                      NaN               NaN
# 2997   2997  NaN       NaN                      NaN               NaN
# 2998   2998  NaN       NaN                      NaN               NaN
# 2999   2999  NaN       NaN                      NaN               NaN
#
# [3000 rows x 5 columns]

# %%
# df1.to_csv(r'F:/6samester/AI/Project/student.csv')
df1=pd.read_csv('F:/6samester/AI/Project/students.csv')
del df1['SR#.1']

# %%
df1.pop("SR#")
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 2995    2995
# 2996    2996
# 2997    2997
# 2998    2998
# 2999    2999
# Name: SR#, Length: 3000, dtype: int64

# %%
df1
# Out:
#      Prog    RollNo                     Name           Domains
# 0     BBA  14K-2712                  Pirkash     deep learning
# 1     BBA  15K-2717             Vinesh Kumar      Data science
# 2     BBA  16K-2709  Syed Taimoor Bin Naseem  Computer Science
# 3     BBA  16K-2723                Sehar Ali  Network Security
# 4     BBA  16K-2736           Muhammad Bilal  Computer Science
# ...   ...       ...                      ...               ...
# 2995  NaN       NaN                      NaN               NaN
# 2996  NaN       NaN                      NaN               NaN
# 2997  NaN       NaN                      NaN               NaN
# 2998  NaN       NaN                      NaN               NaN
# 2999  NaN       NaN                      NaN               NaN
#
# [3000 rows x 4 columns]

# %%
df1.to_csv(r'F:/6samester/AI/Project/Student.csv')

# %%
df1=pd.read_csv('F:/6samester/AI/Project/students.csv')
# df1.dropna()
df1
# Out:
#        SR#    Prog    RollNo                       Name  \
# 0       16  BS(CS)  12K-2152             Wasif Ali Khan
# 1       17  BS(CS)  13K-2178              Deedag Baloch
# 2       18  BS(CS)  14K-2028            Muhammad Muteeb
# 3       19  BS(CS)  14K-2128             Muhammad Azeem
# 4       20  BS(CS)  14K-2213         Mubeen Alam Usmani
# ...    ...     ...       ...                        ...
# 2014  2093  BS(SE)  19K-1100               Hammad Ahmed
# 2015  2094  BS(SE)  19K-1106                Fizza Zakir
# 2016  2095  BS(SE)  19K-1111       M Aamir Hassan Malik
# 2017  2096  BS(SE)  19K-1116                     Sarmad
# 2018  2097  BS(SE)  19K-1121  Syed Muhammad Wahaj Kazmi
#
#                               Domains
# 0                    Machine Learning
# 1                     Web development
# 2             Artificial Intellegence
# 3                      Cyber Security
# 4                  internet of things
# ...                               ...
# ...

# %%
# df1.drop(index='BBA',columns='Prog')
# data_with_index = df1.set_index("Prog")
# df1.to_csv(r'F:/6samester/AI/Project/Student.csv')
print(df1['Prog']=='BBA')
df1['Prog'].isnull().values.any()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2014    False
# 2015    False
# 2016    False
# 2017    False
# 2018    False
# Name: Prog, Length: 2019, dtype: bool
# False

# %%
# data_with_index = data_with_index.drop("BBA",axis=0)
# data_with_index.drop('BBA')

# %%
df2=pd.read_csv('F:/6samester/AI/Project/Teachers.csv')

# %%
df2
# Out:
#      Unnamed: 0  SR#1            Names                      email
# 0             0     0       Atif Tahir       atif.tahir@nu.edu.pk
# 1             1     1   Zulfiqar Memon   zulfiqar.memon@nu.edu.pk
# 2             2     2    Jawwad Shamsi    jawwad.shamsi@nu.edu.pk
# 3             3     3    Ghufran Ahmed    ghufran.ahmed@nu.edu.pk
# 4             4     4    Suffian Hamed    suffian.hamed@nu.edu.pk
# ..          ...   ...              ...                        ...
# 183         183   183        Ali Fatmi        ali.fatmi@nu.edu.pk
# 184         184   184  Muhammad Nadeem  muhammad.nadeem@nu.edu.pk
# 185         185   185              NaN                        NaN
# 186         186   186              NaN                        NaN
# 187         187   187              NaN                        NaN
#
# [188 rows x 4 columns]

# %%
for i in range(0,188):
    df2.loc[i,['SR#']] = i

# %%
df2
# Out:
#      SR#
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
# ..   ...
# 183  183
# 184  184
# 185  185
# 186  186
# 187  187
#
# [188 rows x 1 columns]

# %%
# df2.to_csv(r'F:/6samester/AI/Project/teachers.csv')

# %%
# df3=pd.read_csv('F:/6samester/AI/Project/Teachers.csv')

# %%
df3
# Out:
#      SR#1            Names                      email
# 0       0       Atif Tahir       atif.tahir@nu.edu.pk
# 1       1   Zulfiqar Memon   zulfiqar.memon@nu.edu.pk
# 2       2    Jawwad Shamsi    jawwad.shamsi@nu.edu.pk
# 3       3    Ghufran Ahmed    ghufran.ahmed@nu.edu.pk
# 4       4    Suffian Hamed    suffian.hamed@nu.edu.pk
# ..    ...              ...                        ...
# 183   183        Ali Fatmi        ali.fatmi@nu.edu.pk
# 184   184  Muhammad Nadeem  muhammad.nadeem@nu.edu.pk
# 185   185              NaN                        NaN
# 186   186              NaN                        NaN
# 187   187              NaN                        NaN
#
# [188 rows x 3 columns]

# %%
df3.dropna()
# Out:
#      SR#1            Names                      email
# 0       0       Atif Tahir       atif.tahir@nu.edu.pk
# 1       1   Zulfiqar Memon   zulfiqar.memon@nu.edu.pk
# 2       2    Jawwad Shamsi    jawwad.shamsi@nu.edu.pk
# 3       3    Ghufran Ahmed    ghufran.ahmed@nu.edu.pk
# 4       4    Suffian Hamed    suffian.hamed@nu.edu.pk
# ..    ...              ...                        ...
# 180   180      Rauf Malick      rauf.malick@nu.edu.pk
# 181   181      Ubaid Aftab      ubaid.aftab@nu.edu.pk
# 182   182     Rubab Jaffar     rubab.jaffar@nu.edu.pk
# 183   183        Ali Fatmi        ali.fatmi@nu.edu.pk
# 184   184  Muhammad Nadeem  muhammad.nadeem@nu.edu.pk
#
# [181 rows x 3 columns]

# %%
# df3.to_csv(r'F:/6samester/AI/Project/teachers.csv')

# %%
# Out:
#      SR#1           Names               email
# 161   161  Sumaiyah@Nu Nu  sumaiyah@nu.edu.pk

# %%
df4=pd.read_csv('F:/6samester/AI/Project/Teachers.csv')

# %%
df4
# Out:
#     SR#1            Names                      email
# 0      0       Atif Tahir       atif.tahir@nu.edu.pk
# 1      1   Zulfiqar Memon   zulfiqar.memon@nu.edu.pk
# 2      2    Jawwad Shamsi    jawwad.shamsi@nu.edu.pk
# 3      3    Ghufran Ahmed    ghufran.ahmed@nu.edu.pk
# 4      4    Suffian Hamed    suffian.hamed@nu.edu.pk
# ..   ...              ...                        ...
# 56    56      Rauf Malick      rauf.malick@nu.edu.pk
# 57    57      Ubaid Aftab      ubaid.aftab@nu.edu.pk
# 58    58     Rubab Jaffar     rubab.jaffar@nu.edu.pk
# 59    59        Ali Fatmi        ali.fatmi@nu.edu.pk
# 60    60  Muhammad Nadeem  muhammad.nadeem@nu.edu.pk
#
# [61 rows x 3 columns]

# %%
df4.dropna()
# Out:
#      Unnamed: 0  SR#1            Names                      email
# 0             0     0       Atif Tahir       atif.tahir@nu.edu.pk
# 1             1     1   Zulfiqar Memon   zulfiqar.memon@nu.edu.pk
# 2             2     2    Jawwad Shamsi    jawwad.shamsi@nu.edu.pk
# 3             3     3    Ghufran Ahmed    ghufran.ahmed@nu.edu.pk
# 4             4     4    Suffian Hamed    suffian.hamed@nu.edu.pk
# ..          ...   ...              ...                        ...
# 180         180   180      Rauf Malick      rauf.malick@nu.edu.pk
# 181         181   181      Ubaid Aftab      ubaid.aftab@nu.edu.pk
# 182         182   182     Rubab Jaffar     rubab.jaffar@nu.edu.pk
# 183         183   183        Ali Fatmi        ali.fatmi@nu.edu.pk
# 184         184   184  Muhammad Nadeem  muhammad.nadeem@nu.edu.pk
#
# [181 rows x 4 columns]

# %%
df4.drop_duplicates(subset ="email", inplace = True)

# %%
df4
# Out:
#     Unnamed: 0  SR#1            Names                      email
# 0            0     0       Atif Tahir       atif.tahir@nu.edu.pk
# 1            1     1   Zulfiqar Memon   zulfiqar.memon@nu.edu.pk
# 2            2     2    Jawwad Shamsi    jawwad.shamsi@nu.edu.pk
# 3            3     3    Ghufran Ahmed    ghufran.ahmed@nu.edu.pk
# 4            4     4    Suffian Hamed    suffian.hamed@nu.edu.pk
# ..         ...   ...              ...                        ...
# 57          57    57      Ubaid Aftab      ubaid.aftab@nu.edu.pk
# 58          58    58     Rubab Jaffar     rubab.jaffar@nu.edu.pk
# 59          59    59        Ali Fatmi        ali.fatmi@nu.edu.pk
# 60          60    60  Muhammad Nadeem  muhammad.nadeem@nu.edu.pk
# 61          61    61              NaN                        NaN
#
# [62 rows x 4 columns]

# %%
df4.dropna()
# Out:
#     Unnamed: 0  SR#1            Names                      email
# 0            0     0       Atif Tahir       atif.tahir@nu.edu.pk
# 1            1     1   Zulfiqar Memon   zulfiqar.memon@nu.edu.pk
# 2            2     2    Jawwad Shamsi    jawwad.shamsi@nu.edu.pk
# 3            3     3    Ghufran Ahmed    ghufran.ahmed@nu.edu.pk
# 4            4     4    Suffian Hamed    suffian.hamed@nu.edu.pk
# ..         ...   ...              ...                        ...
# 56          56    56      Rauf Malick      rauf.malick@nu.edu.pk
# 57          57    57      Ubaid Aftab      ubaid.aftab@nu.edu.pk
# 58          58    58     Rubab Jaffar     rubab.jaffar@nu.edu.pk
# 59          59    59        Ali Fatmi        ali.fatmi@nu.edu.pk
# 60          60    60  Muhammad Nadeem  muhammad.nadeem@nu.edu.pk
#
# [61 rows x 4 columns]

# %%
# df4.to_csv(r'F:/6samester/AI/Project/teachers.csv')

# %%
df5=pd.read_csv('F:/6samester/AI/Project/Teachers.csv')

# %%
df5
# Out:
#     SR#1            Names                      email
# 0      0       Atif Tahir       atif.tahir@nu.edu.pk
# 1      1   Zulfiqar Memon   zulfiqar.memon@nu.edu.pk
# 2      2    Jawwad Shamsi    jawwad.shamsi@nu.edu.pk
# 3      3    Ghufran Ahmed    ghufran.ahmed@nu.edu.pk
# 4      4    Suffian Hamed    suffian.hamed@nu.edu.pk
# ..   ...              ...                        ...
# 56    56      Rauf Malick      rauf.malick@nu.edu.pk
# 57    57      Ubaid Aftab      ubaid.aftab@nu.edu.pk
# 58    58     Rubab Jaffar     rubab.jaffar@nu.edu.pk
# 59    59        Ali Fatmi        ali.fatmi@nu.edu.pk
# 60    60  Muhammad Nadeem  muhammad.nadeem@nu.edu.pk
#
# [61 rows x 3 columns]

# %%
fieldsList=['Computer Science',
'Computer Engineering',
'Information Systems',
'Information Technology (IT)',
'Information Science',
      'Cyber Security',
      'deep learning',
      'Natural Processing Language NLP',
      'Machine Learning',
      ]

fieldsList2=['Web development',
      'Mobile Application Development',
      'Network Security',
      'Artificial Intellegence',
      'internet of things',
      'Data science','Data bases','computer vision','virtual Reality']

# %%
for i in range(0,2098):
    df5.loc[i,['Domain1']] = random.choice(fieldsList)

# %%
df5
# Out:
#       SR#1           Names                     email  \
# 0      0.0      Atif Tahir      atif.tahir@nu.edu.pk
# 1      1.0  Zulfiqar Memon  zulfiqar.memon@nu.edu.pk
# 2      2.0   Jawwad Shamsi   jawwad.shamsi@nu.edu.pk
# 3      3.0   Ghufran Ahmed   ghufran.ahmed@nu.edu.pk
# 4      4.0   Suffian Hamed   suffian.hamed@nu.edu.pk
# ...    ...             ...                       ...
# 2093   NaN             NaN                       NaN
# 2094   NaN             NaN                       NaN
# 2095   NaN             NaN                       NaN
# 2096   NaN             NaN                       NaN
# 2097   NaN             NaN                       NaN
#
#                              Domains
# 0            Artificial Intellegence
# 1                Information Science
# 2                     Cyber Security
# 3                 internet of things
# 4                   Machine Learning
# ...                              ...
# 2093             Information Systems
# ...

# %%
Designation=['Professor','Assistant Professor','Lecturer','Instructor']

# %%
for i in range(0,60):
    df5.loc[i,['Designation']] = random.choice(Designation)

# %%
df5.dropna()
# Out:
#     SR#1              Names                        email  \
# 0    0.0         Atif Tahir         atif.tahir@nu.edu.pk
# 1    1.0     Zulfiqar Memon     zulfiqar.memon@nu.edu.pk
# 2    2.0      Jawwad Shamsi      jawwad.shamsi@nu.edu.pk
# 3    3.0      Ghufran Ahmed      ghufran.ahmed@nu.edu.pk
# 4    4.0      Suffian Hamed      suffian.hamed@nu.edu.pk
# 5    5.0           Mshahzed           mshahzed@nu.edu.pk
# 6    6.0    Muhammad Nouman    muhammad.nouman@nu.edu.pk
# 7    7.0       Hassan Jamil       hassan.jamil@nu.edu.pk
# 8    8.0        Nadeem Kafi        nadeem.kafi@nu.edu.pk
# 9    9.0     Farrukh Hassan     farrukh.hassan@nu.edu.pk
# 10  10.0     Fahad Sherwani     fahad.sherwani@nu.edu.pk
# 11  11.0         Aqsa Aslam         aqsa.aslam@nu.edu.pk
# 12  12.0              Safia              safia@nu.edu.pk
# 13  13.0       Nida Munawar       nida.munawar@nu.edu.pk
# 14  14.0     Rizwan Qureshi     rizwan.qureshi@nu.edu.pk
# ...

# %%
 df5.to_csv(r'F:/6samester/AI/Project/teachers.csv')

# %%
import pandas as pd
df6=pd.read_csv('F:/6samester/AI/Project/students.csv')
df6
# Out:
#        SR#    Prog    RollNo                       Name  \
# 0       16  BS(CS)  12K-2152             Wasif Ali Khan
# 1       17  BS(CS)  13K-2178              Deedag Baloch
# 2       18  BS(CS)  14K-2028            Muhammad Muteeb
# 3       19  BS(CS)  14K-2128             Muhammad Azeem
# 4       20  BS(CS)  14K-2213         Mubeen Alam Usmani
# ...    ...     ...       ...                        ...
# 2014  2093  BS(SE)  19K-1100               Hammad Ahmed
# 2015  2094  BS(SE)  19K-1106                Fizza Zakir
# 2016  2095  BS(SE)  19K-1111       M Aamir Hassan Malik
# 2017  2096  BS(SE)  19K-1116                     Sarmad
# 2018  2097  BS(SE)  19K-1121  Syed Muhammad Wahaj Kazmi
#
#                               Domains
# 0                    Machine Learning
# 1                     Web development
# 2             Artificial Intellegence
# 3                      Cyber Security
# 4                  internet of things
# ...                               ...
# ...

# %%
#FOR WEB DEVELOPMENT

# skill1 =['node Js','React js', 'Angular','JavaScript','Vue js','Django','Flask','HTML5','CSS','.NET','PHP','Bootstrap','JQuery','Ajax','python']
# for i in range(0,2017):
#     df6.loc[i,['SR#']] = i
# web=df6.loc[df6['Domains'] == 'Web development'] 
# loc=web['SR#']
# for i in loc:
#     df6.loc[i,['Skill5']] = random.choice(skill1)
# df6.loc[df6['Domains'] == 'Web development']

# %%
Skills=['node Js','React js', 'Angular','JavaScript','Vue js','Django','Flask','HTML5','CSS','.NET','PHP','Bootstrap','JQuery','Ajax',
        'python','numpy','pandas','java','kotlin','flutter','sql','mongoDB','firebase','swift','laravel','ASP.NET']
# Out:
#        SR#    Prog    RollNo                       Name  \
# 0       16  BS(CS)  12K-2152             Wasif Ali Khan
# 1       17  BS(CS)  13K-2178              Deedag Baloch
# 2       18  BS(CS)  14K-2028            Muhammad Muteeb
# 3       19  BS(CS)  14K-2128             Muhammad Azeem
# 4       20  BS(CS)  14K-2213         Mubeen Alam Usmani
# ...    ...     ...       ...                        ...
# 2014  2093  BS(SE)  19K-1100               Hammad Ahmed
# 2015  2094  BS(SE)  19K-1106                Fizza Zakir
# 2016  2095  BS(SE)  19K-1111       M Aamir Hassan Malik
# 2017  2096  BS(SE)  19K-1116                     Sarmad
# 2018  2097  BS(SE)  19K-1121  Syed Muhammad Wahaj Kazmi
#
#                               Domains
# 0                    Machine Learning
# 1                     Web development
# 2             Artificial Intellegence
# 3                      Cyber Security
# 4                  internet of things
# ...                               ...
# ...

# %%
df6=df6.drop(['Domains'],axis=1)

# %%
# df6
for i in range(0,2098):
    df6.loc[i,['Domain2']] = random.choice(fieldsList2)

# %%
df6
# Out:
#        SR#    Prog    RollNo                Name      SKILL1           SKILL2  \
# 0     16.0  BS(CS)  12K-2152      Wasif Ali Khan    firebase           kotlin
# 1     17.0  BS(CS)  13K-2178       Deedag Baloch     node Js            numpy
# 2     18.0  BS(CS)  14K-2028     Muhammad Muteeb    React js          mongoDB
# 3     19.0  BS(CS)  14K-2128      Muhammad Azeem      Django  Data Structures
# 4     20.0  BS(CS)  14K-2213  Mubeen Alam Usmani    firebase             java
# ...    ...     ...       ...                 ...         ...              ...
# 2093   NaN     NaN       NaN                 NaN     Angular           kotlin
# 2094   NaN     NaN       NaN                 NaN       Flask             Ajax
# 2095   NaN     NaN       NaN                 NaN       Flask          flutter
# 2096   NaN     NaN       NaN                 NaN     Angular           kotlin
# 2097   NaN     NaN       NaN                 NaN  .NETopenCv             java
#
# ...

# %%
for i in range(0,2098):
    df6.loc[i,['Domain2']] = random.choice(fieldsList2)

# %%
df6
# Out:
#        SR#    Prog    RollNo                Name  \
# 0     16.0  BS(CS)  12K-2152      Wasif Ali Khan
# 1     17.0  BS(CS)  13K-2178       Deedag Baloch
# 2     18.0  BS(CS)  14K-2028     Muhammad Muteeb
# 3     19.0  BS(CS)  14K-2128      Muhammad Azeem
# 4     20.0  BS(CS)  14K-2213  Mubeen Alam Usmani
# ...    ...     ...       ...                 ...
# 2093   NaN     NaN       NaN                 NaN
# 2094   NaN     NaN       NaN                 NaN
# 2095   NaN     NaN       NaN                 NaN
# 2096   NaN     NaN       NaN                 NaN
# 2097   NaN     NaN       NaN                 NaN
#
#                               Domain1                         Domain2
# 0                 Information Science              internet of things
# 1                    Computer Science                 virtual Reality
# 2                 Information Systems  Mobile Application Development
# 3                    Machine Learning                Network Security
# ...

# %%
skill1=['node Js','React js', 'Angular','JavaScript','Vue js','Django','Flask','.NET''openCv','firebase']
skill2=['PHP','Bootstrap','Ajax','python','numpy','pandas','java','kotlin','flutter','mongoDB','c#','Data Structures']
skill3=['sql','swift','laravel','ASP.NET','ajax','TensorFlow','pytorch','JQuery','HTML5','CSS']
skill4=['swift','JAVA','C++','AWS','Matlab','mysqli','React Native','SAAS']
skill5=['Spring Framework','Express','Adobe illutration','UIkit','Materialize','C']

# %%
for i in range(0,2098):
    df6.loc[i,['SKILL5']] = random.choice(skill5)

# %%
# df6
import random
import decimal

for i in range(0,2020):
    df6.loc[i,['CGPA']] =float(decimal.Decimal(random.randrange(155,389))/100)
    
df6
# Out:
#        SR#    Prog    RollNo                Name                  Domains  \
# 0     16.0  BS(CS)  12K-2152      Wasif Ali Khan         Machine Learning
# 1     17.0  BS(CS)  13K-2178       Deedag Baloch          Web development
# 2     18.0  BS(CS)  14K-2028     Muhammad Muteeb  Artificial Intellegence
# 3     19.0  BS(CS)  14K-2128      Muhammad Azeem           Cyber Security
# 4     20.0  BS(CS)  14K-2213  Mubeen Alam Usmani       internet of things
# ...    ...     ...       ...                 ...                      ...
# 2093   NaN     NaN       NaN                 NaN                      NaN
# 2094   NaN     NaN       NaN                 NaN                      NaN
# 2095   NaN     NaN       NaN                 NaN                      NaN
# 2096   NaN     NaN       NaN                 NaN                      NaN
# 2097   NaN     NaN       NaN                 NaN                      NaN
#
#           SKILL1           SKILL2   SKILL3        SKILL4             SKILL5  \
# ...

# %%
# df6.dropna()
# df6
df6.to_csv(r'F:/6samester/AI/Project/students.csv')

# %%
import pandas as pd
df7=pd.read_csv('F:/6samester/AI/Project/teachers.csv')
df7
# Out:
#     SR#1            Names                      email  \
# 0      0       Atif Tahir       atif.tahir@nu.edu.pk
# 1      1   Zulfiqar Memon   zulfiqar.memon@nu.edu.pk
# 2      2    Jawwad Shamsi    jawwad.shamsi@nu.edu.pk
# 3      3    Ghufran Ahmed    ghufran.ahmed@nu.edu.pk
# 4      4    Suffian Hamed    suffian.hamed@nu.edu.pk
# ..   ...              ...                        ...
# 56    56      Rauf Malick      rauf.malick@nu.edu.pk
# 57    57      Ubaid Aftab      ubaid.aftab@nu.edu.pk
# 58    58     Rubab Jaffar     rubab.jaffar@nu.edu.pk
# 59    59        Ali Fatmi        ali.fatmi@nu.edu.pk
# 60    60  Muhammad Nadeem  muhammad.nadeem@nu.edu.pk
#
#                            Domains          Designation
# 0          Artificial Intellegence           Instructor
# 1              Information Science  Assistant Professor
# 2                   Cyber Security  Assistant Professor
# 3               internet of things            Professor
# ...

# %%
# df7.drop(['Domains'])
df7
# Out:
#     SR#1            Names                      email  \
# 0      0       Atif Tahir       atif.tahir@nu.edu.pk
# 1      1   Zulfiqar Memon   zulfiqar.memon@nu.edu.pk
# 2      2    Jawwad Shamsi    jawwad.shamsi@nu.edu.pk
# 3      3    Ghufran Ahmed    ghufran.ahmed@nu.edu.pk
# 4      4    Suffian Hamed    suffian.hamed@nu.edu.pk
# ..   ...              ...                        ...
# 56    56      Rauf Malick      rauf.malick@nu.edu.pk
# 57    57      Ubaid Aftab      ubaid.aftab@nu.edu.pk
# 58    58     Rubab Jaffar     rubab.jaffar@nu.edu.pk
# 59    59        Ali Fatmi        ali.fatmi@nu.edu.pk
# 60    60  Muhammad Nadeem  muhammad.nadeem@nu.edu.pk
#
#                            Domains          Designation
# 0          Artificial Intellegence           Instructor
# 1              Information Science  Assistant Professor
# 2                   Cyber Security  Assistant Professor
# 3               internet of things            Professor
# ...

# %%
# df7=df7.drop(['Designation'],axis=1)
# df7
designation=['Assistant Professor','Professor']


for i in range(0,2020):
    df7.loc[i,['Designation']] =random.choice(designation)
  
# for i in range(0,2020):
#     df7.loc[i,['CGPA']] =float(decimal.Decimal(random.randrange(155,389))/100)

# %%
# df7=df7.drop(['Designation'],axis=1)
df7
# Out:
#       SR#1           Names                     email          Designation
# 0      0.0      Atif Tahir      atif.tahir@nu.edu.pk            Professor
# 1      1.0  Zulfiqar Memon  zulfiqar.memon@nu.edu.pk  Assistant Professor
# 2      2.0   Jawwad Shamsi   jawwad.shamsi@nu.edu.pk  Assistant Professor
# 3      3.0   Ghufran Ahmed   ghufran.ahmed@nu.edu.pk  Assistant Professor
# 4      4.0   Suffian Hamed   suffian.hamed@nu.edu.pk            Professor
# ...    ...             ...                       ...                  ...
# 2015   NaN             NaN                       NaN            Professor
# 2016   NaN             NaN                       NaN  Assistant Professor
# 2017   NaN             NaN                       NaN  Assistant Professor
# 2018   NaN             NaN                       NaN            Professor
# 2019   NaN             NaN                       NaN  Assistant Professor
#
# [2020 rows x 4 columns]

# %%
for i in range(0,2098):
    df7.loc[i,['Domain2']] = random.choice(fieldsList)

# %%
df7
# Out:
#       SR#1           Names                     email          Designation  \
# 0      0.0      Atif Tahir      atif.tahir@nu.edu.pk            Professor
# 1      1.0  Zulfiqar Memon  zulfiqar.memon@nu.edu.pk  Assistant Professor
# 2      2.0   Jawwad Shamsi   jawwad.shamsi@nu.edu.pk  Assistant Professor
# 3      3.0   Ghufran Ahmed   ghufran.ahmed@nu.edu.pk  Assistant Professor
# 4      4.0   Suffian Hamed   suffian.hamed@nu.edu.pk            Professor
# ...    ...             ...                       ...                  ...
# 2093   NaN             NaN                       NaN                  NaN
# 2094   NaN             NaN                       NaN                  NaN
# 2095   NaN             NaN                       NaN                  NaN
# 2096   NaN             NaN                       NaN                  NaN
# 2097   NaN             NaN                       NaN                  NaN
#
#                       Domain1                          Domain2
# ...

# %%
ReqGpa=[3.00,3.8,2.8,2.00,2.5,2.7,3.33,3.5]
for i in range(0,2098):
    df7.loc[i,['Req CGPA']] = random.choice(ReqGpa)

# %%
df7
# Out:
#       SR#1           Names                     email          Designation  \
# 0      0.0      Atif Tahir      atif.tahir@nu.edu.pk            Professor
# 1      1.0  Zulfiqar Memon  zulfiqar.memon@nu.edu.pk  Assistant Professor
# 2      2.0   Jawwad Shamsi   jawwad.shamsi@nu.edu.pk  Assistant Professor
# 3      3.0   Ghufran Ahmed   ghufran.ahmed@nu.edu.pk  Assistant Professor
# 4      4.0   Suffian Hamed   suffian.hamed@nu.edu.pk            Professor
# ...    ...             ...                       ...                  ...
# 2093   NaN             NaN                       NaN                  NaN
# 2094   NaN             NaN                       NaN                  NaN
# 2095   NaN             NaN                       NaN                  NaN
# 2096   NaN             NaN                       NaN                  NaN
# 2097   NaN             NaN                       NaN                  NaN
#
#                       Domain1                          Domain2  Req CGPA
# ...

# %%
Frameworks1=['node Js','React js', 'Angular','.NET','Spring Framework','Bootstrap','Ajax','flutter','SAAS','Django']
frameworks2= ['React Native','JQuery','Vue js','Flask','Vue js','Django','Flask','ajax','laravel','ASP.NET','UIkit','Materialize']
lib=['AWS','Matlab','numpy','pandas','openCv','TensorFlow','pytorch','Express']
for i in range(0,2098):
    df7.loc[i,['Req Skill3']] = random.choice(lib)

# %%
df7
# Out:
#       SR#1           Names                     email          Designation  \
# 0      0.0      Atif Tahir      atif.tahir@nu.edu.pk            Professor
# 1      1.0  Zulfiqar Memon  zulfiqar.memon@nu.edu.pk  Assistant Professor
# 2      2.0   Jawwad Shamsi   jawwad.shamsi@nu.edu.pk  Assistant Professor
# 3      3.0   Ghufran Ahmed   ghufran.ahmed@nu.edu.pk  Assistant Professor
# 4      4.0   Suffian Hamed   suffian.hamed@nu.edu.pk            Professor
# ...    ...             ...                       ...                  ...
# 2093   NaN             NaN                       NaN                  NaN
# 2094   NaN             NaN                       NaN                  NaN
# 2095   NaN             NaN                       NaN                  NaN
# 2096   NaN             NaN                       NaN                  NaN
# 2097   NaN             NaN                       NaN                  NaN
#
#                       Domain1                          Domain2  Req CGPA  \
# ...

# %%
df7=df7.dropna()

# %%
df7
# Out:
#     SR#1            Names                      email          Designation  \
# 0    0.0       Atif Tahir       atif.tahir@nu.edu.pk            Professor
# 1    1.0   Zulfiqar Memon   zulfiqar.memon@nu.edu.pk  Assistant Professor
# 2    2.0    Jawwad Shamsi    jawwad.shamsi@nu.edu.pk  Assistant Professor
# 3    3.0    Ghufran Ahmed    ghufran.ahmed@nu.edu.pk  Assistant Professor
# 4    4.0    Suffian Hamed    suffian.hamed@nu.edu.pk            Professor
# ..   ...              ...                        ...                  ...
# 56  56.0      Rauf Malick      rauf.malick@nu.edu.pk  Assistant Professor
# 57  57.0      Ubaid Aftab      ubaid.aftab@nu.edu.pk            Professor
# 58  58.0     Rubab Jaffar     rubab.jaffar@nu.edu.pk            Professor
# 59  59.0        Ali Fatmi        ali.fatmi@nu.edu.pk  Assistant Professor
# 60  60.0  Muhammad Nadeem  muhammad.nadeem@nu.edu.pk            Professor
#
#                     Domain1               Domain2  Req CGPA        Req Skill1  \
# ...

# %%
df7.to_csv(r'F:/6samester/AI/Project/teachers.csv')
